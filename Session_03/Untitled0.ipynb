# %%
# STARTER CODE - DO NOT DELETE!

import csv
# option 1:
#if you upload the file to session storge, uncomment the following line:
#with open('IMDB_reviews.csv') as f:
#option 2:
#if you uplaod the file to your drive, edit and uncomment the following line:
with open('/drive/MyDrive/Summer_21/BA765/IMDB_reviews.csv') as f:
    reader = csv.reader(f)
    a1 = list(reader)
print("csv to list:",a1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-9973787e8213> in <module>()
#       7 #option 2:
#       8 #if you uplaod the file to your drive, edit and uncomment the following line:
# ----> 9 with open('/drive/MyDrive/Summer_21/BA765/IMDB_reviews.csv') as f:
#      10     reader = csv.reader(f)
#      11     a1 = list(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/drive/MyDrive/Summer_21/BA765/IMDB_reviews.csv'

# %% [markdown]
# <br> what does Br do
